# %%
import nuc_counts

# %%
nc = nuc_counts.particle_count("C:/Users/91882/Desktop/nuclear count2.xlsx","Xi")
# Out:
# Sigma is  56.32877062390052
# mean of xi(m) is  2797.64

# %%
nc.table()#to show toble
# Out:
#       Xi    (Xi-m)^2      P(X)
# 0   2990  37002.3696  0.000021
# 1   2644  23605.2496  0.000172
# 2   2671  16037.6896  0.000566
# 3   2923  15715.1296  0.000595
# 4   2898  10072.1296  0.001449
# 5   2698   9928.1296  0.001482
# 6   2897   9872.4096  0.001495
# 7   2896   9674.6896  0.001542
# 8   2709   7857.0496  0.002054
# 9   2710   7680.7696  0.002112
# 10  2885   7631.7696  0.002128
# 11  2711   7506.4896  0.002171
# 12  2712   7334.2096  0.002230
# 13  2882   7116.6096  0.002308
# 14  2882   7116.6096  0.002308
# 15  2715   6829.3696  0.002415
# 16  2878   6457.7296  0.002561
# 17  2722   5721.4096  0.002876
# 18  2870   5235.9696  0.003104
# 19  2869   5092.2496  0.003175
# 20  2868   4950.5296  0.003247
# 21  2728   4849.7296  0.003299
# 22  2867   4810.8096  0.003319
# 23  2865   4537.3696  0.003465
# 24  2865   4537.3696  0.003465
# 25  2733   4178.3296  0.003667
# 26  2735   3923.7696  0.003817
# 27  2860   3888.7696  0.003838
# 28  2736   3799.4896  0.003893
# ...

# %%
nc.savetable("nc")#to save data in excel format

# %%
nc.plot() #to show plot

# %%
nc.saveplot("nc")#to save plot in jpg format
